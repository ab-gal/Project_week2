# %%
import pandas as pd

# %%
df=pd.read_excel('GSAF5.xls')

# %%
#!pip install pandas openpyxl xlrd

# %%
df.head()
# Out:
#              Date    Year        Type     Country                  State  \
# 0    14th October  2025.0  Unprovoked    Columbia   Bolivar, del Isolate
# 1    11th October  2025.0  Unprovoked   Australia             Queensland
# 2     7th October  2025.0  Unprovoked   Australia        South Australia
# 3  29th September  2025.0  Unprovoked         USA         Off California
# 4  27th September  2025.0    Provoked  Costa Rica                    NaN
#
#                          Location               Activity                Name  \
# 0               Catagena Province   Swimming with sharks          Male child
# 1  Cook Esplanade Thursday Island       Fishing/swimming          Samuel Nai
# 2                 Kangaroo Island                Surfing        Lee Berryman
# 3                 Catalina Island               Swimming  Christopher Murray
# 4                   Cocos Islands  Diving-Tagging sharks  Dr. Mauricio Hoyos
#
#   Sex  Age  ...             Species   \
# ...

# %%
#filters the columns from the original source
df.columns = df.columns.str.strip()
SAdf = df[["Year", "Date", "Time", "Type", "Sex", "Age", "Activity", "Location", "Country", "State", "Fatal Y/N"]]
SAdf
# Out:
#         Year            Date        Time        Type Sex  Age  \
# 0     2025.0    14th October  Not stated  Unprovoked   M   14
# 1     2025.0    11th October    1823 hrs  Unprovoked   M   14
# 2     2025.0     7th October     1330hrs  Unprovoked   M  50+
# 3     2025.0  29th September     0100hrs  Unprovoked   M   54
# 4     2025.0  27th September  Not stated    Provoked   M   48
# ...      ...             ...         ...         ...  ..  ...
# 7045     0.0     Before 1903         NaN  Unprovoked   M  NaN
# 7046     0.0     Before 1903         NaN  Unprovoked   M  NaN
# 7047     0.0       1900-1905         NaN  Unprovoked   M  NaN
# 7048     0.0       1883-1889         NaN  Unprovoked   M  NaN
# 7049     0.0       1845-1853         NaN  Unprovoked   M   15
#
#                    Activity                             Location  \
# 0      Swimming with sharks                    Catagena Province
# 1          Fishing/swimming       Cook Esplanade Thursday Island
# ...

# %%
#SAdf.Year=SAdf['Year'].map(int)
#SAdf['Year'] = SAdf['Year'].astype(int)
SAdf['Year'] = SAdf['Year'].apply(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 #SAdf.Year=SAdf['Year'].map(int)
#       2 #SAdf['Year'] = SAdf['Year'].astype(int)
# ----> 3 SAdf['Year'] = SAdf['Year'].apply(int)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# ...

# %%
#filters the rows of USA and from 2009.
SAdf = SAdf[ (SAdf['Country'] == 'USA') & (SAdf['Year'] > 2009) ]
SAdf

# %%
SAdf.value_counts("Country""Activity", "Sex", "Age", "Injury", "Fatal Y/N", "Source", "original order")

# %%
SAdf.value_counts("original order")

# %%
SAdf.describe(include="all")

# %%
SAdf.shape

# %%
SAdf.info()

# %%
SAdf.nunique()

# %%
SAdf.dtypes

# %%
SAdf.select_dtypes(include=['int','float'])

# %%
SAdf.value_counts("Country")

# %%
SAdf

# %%
SAdf = df[["Year", "Date", "Time", "Type", "Sex", "Age", "Activity", "Location", "Country", "State", "Fatal Y/N"]]
SAdf

# %%
SAdf.value_counts("Activity")

# %%
SAdf.value_counts("Year")

# %%
pd.set_option('display.max_rows', None)
SAdf.value_counts("Year")

# %%
pd.set_option('display.max_rows', None)
SAdf.value_counts("Year")
